# %% [markdown]
# <font size="6">Plot alternatives and base profies</font>
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/cghiaus/ELECTRE_Tri/main?labpath=docs%2Fhow_to_guides%2Fplot_alternative_and_base_profile.ipynb)

# %% [markdown]
# The profiles of the alternatives and of the bases can be easier to interpret when represented graphically. They can be visulaised by using the functions `plot_alternatives_vs_base_profile()` and `plot_base_profiles_vs_alternative()`.

# %%
"""
Append `src/` directory to `path`
"""
import sys
import os

notebook_dir = os.path.dirname(os.path.abspath('__file__'))
project_root = os.path.dirname(os.path.dirname(notebook_dir))

src_dir = os.path.join(project_root, 'src')
sys.path.append(src_dir)

# %%
import electre_tri as et

# %%
# Problem inputs
data_file = '../../data/mous3docl99_3.csv'
A, B, T, w = et.read_electre_tri_data(data_file)

# %% [markdown]
# # Plot alternatives vs a base profile
#
# In order to visualse all alternatives compared with a base profile, use function `plot_alternatives_vs_base_profile()`. Note that the base profile is represented with its indifference, preference and veto thresholds.

# %%
et.plot_alternatives_vs_base_profile(A, B.iloc[0], T)

# %% [markdown]
# # Plot base profiles vs alternatives
#
# In order to visualse all base profiles compared with an alternative, use function `plot_base_profiles_vs_alternative()`. Note that the alternative is represented with its indifference, preference and veto thresholds.

# %%
et.plot_base_profiles_vs_alternative(B, A.iloc[2], T)
